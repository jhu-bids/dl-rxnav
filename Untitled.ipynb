# %%
import pandas as pd
import psycopg2 as pg

engine = pg.connect("dbname='ohdsi_selected_vocabs' user='sigfried' host='127.0.0.1' port='5432' password='psql'")
df = pd.read_sql('select * from cdm.concept limit 5', con=engine)
display(df)
# Out:
#    concept_id               concept_name domain_id vocabulary_id  \
# 0           0        No matching concept  Metadata          None
# 1        8507                       MALE    Gender        Gender
# 2        8515                      Asian      Race          Race
# 3        8516  Black or African American      Race          Race
# 4        8527                      White      Race          Race
#
#   concept_class_id standard_concept         concept_code valid_start_date  \
# 0        Undefined             None  No matching concept       1970-01-01
# 1           Gender                S                    M       1970-01-01
# 2             Race                S                    2       1970-01-01
# 3             Race                S                    3       1970-01-01
# 4             Race                S                    5       1970-01-01
#
#   valid_end_date invalid_reason
# 0     2099-12-31           None
# 1     2099-12-31           None
# ...
